# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"F:\Data Sets\SalaryData.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30              1.1   39343
# 31              1.3   46205
# 32              1.5   37731
# 33              2.0   43525
# 34              2.2   39891
# 35              2.9   56642
# 36              3.0   60150
# 37              3.2   54445
# 38              3.2   64445
# 39              3.7   57189
# 40              3.9   63218
# 41              4.0   55794
# 42              4.0   56957
# 43              4.1   57081
# 44              4.5   61111
# 45              4.9   67938
# 46              5.1   66029
# 47              5.3   83088
# 48              5.9   81363
# 49              6.0   93940
# 50              6.8   91738
# 51              7.1   98273
# 52              7.9  101302
# 53              8.2  113812
# 54              8.7  109431
# 55              9.0  105582
# 56              9.5  116969
# 57              9.6  112635
# 58             10.3  122391
# 59             10.5  121872

# %%
import statsmodels.formula.api as smf

# %%
m1=smf.ols("YearsExperience ~ Salary",data=df).fit()

# %%
m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        YearsExperience   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     1289.
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           2.58e-41
# Time:                        13:11:14   Log-Likelihood:                -52.336
# No. Observations:                  60   AIC:                             108.7
# Df Residuals:                      58   BIC:                             112.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3832      0.227    -10.480      0.000      -2.838      -1.928
# Salary         0.0001   2.82e-06     35.909      0.000    9.56e-05       0.000
# ==============================================================================
# Omnibus:                        8.765   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                4.189
# Skew:                          -0.412   Prob(JB):                        0.123
# Kurtosis:                       2.003   Cond. No.                     2.41e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x=df.iloc[:,:-1]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
# 30              1.1
# 31              1.3
# 32              1.5
# 33              2.0
# 34              2.2
# 35              2.9
# 36              3.0
# 37              3.2
# 38              3.2
# 39              3.7
# 40              3.9
# 41              4.0
# 42              4.0
# 43              4.1
# 44              4.5
# 45              4.9
# 46              5.1
# 47              5.3
# 48              5.9
# 49              6.0
# 50              6.8
# 51              7.1
# 52              7.9
# 53              8.2
# 54              8.7
# 55              9.0
# 56              9.5
# 57              9.6
# 58             10.3
# 59             10.5

# %%
y=df.iloc[:,1]
y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# 30     39343
# 31     46205
# 32     37731
# 33     43525
# 34     39891
# 35     56642
# 36     60150
# 37     54445
# 38     64445
# 39     57189
# 40     63218
# 41     55794
# 42     56957
# 43     57081
# 44     61111
# 45     67938
# 46     66029
# 47     83088
# 48     81363
# 49     93940
# 50     91738
# 51     98273
# 52    101302
# 53    113812
# 54    109431
# 55    105582
# 56    116969
# 57    112635
# 58    122391
# 59    121872
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state = 0)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (48, 1)
# (48,)
# (12, 1)
# (12,)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([115570.95625576,  53872.76458429, 124919.16711508, 123049.52494321,
#         64155.79652953,  40785.26938125,  47329.01698277, 123049.52494321,
#         63220.9754436 , 100613.81888086,  47329.01698277,  63220.9754436 ])

# %%
y_pred==y_test
# Out:
# 26    False
# 35    False
# 59    False
# 28    False
# 11    False
# 2     False
# 34    False
# 58    False
# 40    False
# 22    False
# 4     False
# 10    False
# Name: Salary, dtype: bool

# %%
import numpy as np

# %%
np.mean(y_pred)
# Out:
# 80593.06729049372

# %%
np.mean(y_test)
# Out:
# 78442.5

# %%
plt.scatter(x_train, y_train, color = "blue")
plt.plot(x_train, reg.predict(x_train))
plt.title('YearsExperience - Salary')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
# Out:
# Text(0,0.5,'Salary')
